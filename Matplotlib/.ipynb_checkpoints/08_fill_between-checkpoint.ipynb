# %%
# %matplotlib ipympl
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data2.csv")
# data

# %%
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data["JavaScript"]

# %%
plt.plot(ages, dev_salaries, color='#444444', linestyle='--', label='All Devs')
# plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.plot(ages, py_salaries, label='Python')
# plt.show()

# %%
plt.legend()
plt.title("Median Salary (USD) by Age")
plt.xlabel('Ages')
plt.ylabel("Median Salary (USD)")
# plt.show()
# Out:
# Text(12.097222222222216, 0.5, 'Median Salary (USD)')

# %%
# filling area
plt.fill_between(ages, py_salaries, alpha=0.25)
# plt.show()

# %%
# using where
overall_median = 57287
plt.fill_between(ages, py_salaries, where=(py_salaries>overall_median), alpha=0.25, label='Above avg')
plt.fill_between(ages, py_salaries, where=(py_salaries>overall_median), alpha=0.25, label='Below avg')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
